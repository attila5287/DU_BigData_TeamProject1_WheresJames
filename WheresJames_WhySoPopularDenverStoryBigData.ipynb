# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt

# %%
file_crime = 'crime.csv'
crime_df = pd.read_csv(file_crime,nrows = 100)
# crime_df.head()
# crime_df.columns ['INCIDENT_ID', 'OFFENSE_ID', 'OFFENSE_CODE', 'OFFENSE_CODE_EXTENSION',
#        'OFFENSE_TYPE_ID', 'OFFENSE_CATEGORY_ID', 'FIRST_OCCURRENCE_DATE',
#        'LAST_OCCURRENCE_DATE', 'REPORTED_DATE', 'INCIDENT_ADDRESS', 'GEO_X',
#        'GEO_Y', 'GEO_LON', 'GEO_LAT', 'DISTRICT_ID', 'PRECINCT_ID',
#        'NEIGHBORHOOD_ID', 'IS_CRIME', 'IS_TRAFFIC'],

#convert string timestamp to_datetime() 
crime_df['test_date'] = pd.to_datetime(crime_df["REPORTED_DATE"])

#call datetime functions on datetime field, year,month,qtr....etc 
crime_df['month']  = crime_df['test_date'].dt.month 
crime_df['month'] = crime_df['month'].map('{:02d}'.format)
crime_df['year']  = crime_df['test_date'].dt.year
crime_df['year-month'] = crime_df["year"].map(str) + '-' + crime_df["month"].map(str)
crime_df.head()
# Out:
#    INCIDENT_ID         OFFENSE_ID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0   2016376978   2016376978521300          5213                       0
# 1  20186000994  20186000994239900          2399                       0
# 2  20166003953  20166003953230500          2305                       0
# 3    201872333    201872333239900          2399                       0
# 4   2017411405   2017411405230300          2303                       0
#
#                 OFFENSE_TYPE_ID       OFFENSE_CATEGORY_ID  \
# 0  weapon-unlawful-discharge-of          all-other-crimes
# 1                   theft-other                   larceny
# 2      theft-items-from-vehicle  theft-from-motor-vehicle
# 3                   theft-other                   larceny
# 4                theft-shoplift                   larceny
#
#     FIRST_OCCURRENCE_DATE   LAST_OCCURRENCE_DATE          REPORTED_DATE  \
# 0   6/15/2016 11:31:00 PM                    NaN  6/15/2016 11:31:00 PM
# ...

# %%
help(datetime)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-191851b23731> in <module>()
# ----> 1 help(datetime)
#
# NameError: name 'datetime' is not defined

# %%
crime_df.head()

# %%
#convert strimg to datetime
